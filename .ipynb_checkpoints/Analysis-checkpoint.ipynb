# %% [markdown]
# ## We require four subsets for the regression analysis
# - All data
# - Countries with above average trade with UK
# - OECD countries
# - EU countries

# %%
import pandas as pd

df = pd.read_csv('cleaned.csv')

# %%
df1 = df.copy()

# %%
#We define a descending list of average trade with UK and use it to get subset 2
import math

tradeflows = df[df['iso3_d'] == 'GBR'].groupby('iso3_o').mean()['tradeflow'].sort_values(ascending=False)
above_average = list(tradeflows[0:math.floor(len(tradeflows)/2)].index)

df2 = df[(df['iso3_d'] == 'GBR') & df['iso3_o'].isin(above_average)].copy()

# %%
#Creating subset 3, using a list of all OECD countries (with iso codes)
OECD = ['AUS', 'AUT', 'BEL', 'CAN','CHE', 'CHL', 'COL', 'CRI', 'CZE', 'DEU', 'DNK', 'ESP', 'EST', 'FIN', 'FRA', 'GBR', 'GRC', 'HUN', 'IRL', 'ISL', 'ISR', 'ITA', 'JPN', 'KOR', 'LTU', 'LUX', 'LVA', 'MEX', 'NLD', 'NOR', 'NZL', 'POL', 'PRT', 'SVK', 'SVN', 'SWE', 'TUR', 'USA']

df3 = df[df['iso3_o'].isin(OECD) & df['iso3_d'].isin(OECD)].copy()

# %%
#Creating subset 4
df4 = df[df['both_eu'] == 1].copy()

# %%
#Spec 1 DF 1 (PPML)
import gme as gme
data = df1.copy()

data['loggdp_o'] = np.log(data['gdp_o'])
data['loggdp_d'] = np.log(data['gdp_d'])
data['logdistw'] = np.log(data['distw'])
data['logtrade'] = np.log(data['tradeflow'])


gme_data = gme.EstimationData(data_frame = data,
                              imp_var_name = 'iso3_d',
                              exp_var_name = 'iso3_o',
                              trade_var_name = 'tradeflow',
                              year_var_name = 'year')
print(gme_data)



gme_model = gme.EstimationModel(estimation_data = gme_data,
                                lhs_var = 'logtrade',
                                rhs_var = ['loggdp_o', 'loggdp_d', 'logdistw'],
                                fixed_effects = ['iso3_d', 'iso3_o'])

model_estimates = gme_model.estimate()

results = model_estimates['all']

#gme_model.format_regression_table(format = "txt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-807f8089cd0b> in <module>
#       1 #Spec 1 DF 1 (PPML)
#       2 import gme as gme
# ----> 3 data = df1.copy()
#       4
#       5 data['loggdp_o'] = np.log(data['gdp_o'])
#
# NameError: name 'df1' is not defined

# %%
o_means = df.groupby('iso3_o').mean()
df[]

# %%
cols = ['distw', 'comlang_off', 'comlang_ethno',
       'comcol', 'col45', 'heg_o', 'heg_d', 'col_dep_ever', 'sibling_ever',
       'gdp_o', 'gdp_d', 'tradeflow', 'both_eu', 'one_eu']

o_means = df.groupby(['iso3_o', 'year']).mean()[cols]
o_means = o_means.reset_index()
o_means = pd.merge(df[['year', 'iso3_o']],o_means,how='left',on=['year', 'iso3_o'])

# %%
demeaned_o = df.copy()
demeaned_o[cols] = df[cols]-o_means[cols]

# %%
d_means = demeaned_o.groupby(['iso3_d', 'year']).mean()[cols]
d_means = d_means.reset_index()
d_means = pd.merge(demeaned_o[['year','iso3_d']],d_means,how='left',on=['year','iso3_d'])

# %%
demeaned_o_d = demeaned_o.copy()
demeaned_o_d[cols] = demeaned_o[cols]-d_means[cols]
# Out:
#          year iso3_d       distw  comlang_off  comlang_ethno    comcol  \
# 0        2001    AFG -874.026949    -0.143501      -0.131295 -0.102741
# 1        2002    AFG -935.945640    -0.144020      -0.131685 -0.101094
# 2        2003    AFG -935.945640    -0.144020      -0.131685 -0.101094
# 3        2004    AFG -943.661370    -0.143555      -0.131266 -0.100043
# 4        2005    AFG -943.661370    -0.143555      -0.131266 -0.100043
# ...       ...    ...         ...          ...            ...       ...
# 1814199  0.707692 -0.005128    0.0 -0.005128     -0.005128      0.656410
# 1814200  0.706186 -0.005155    0.0 -0.005155     -0.005155      0.654639
# 1814201  0.699454 -0.005464    0.0 -0.005464     -0.005464      0.639344
#
#                 gdp_o         gdp_d     tradeflow  both_eu    one_eu
# 0        2.561137e-09 -1.720954e+08  -5585.741951      0.0 -0.148148
# 1       -2.328306e-10 -1.751196e+08  -4169.803949      0.0 -0.146597
# 2       -8.614734e-09 -1.967249e+08  -4955.586353      0.0 -0.146597
# 3       -3.259629e-09 -2.203356e+08  -9946.778816      0.0 -0.145833
# 4        5.587935e-09 -2.378047e+08 -12938.628469      0.0 -0.145833
# ...               ...           ...           ...      ...       ...
# 1814197  6.519258e-08 -3.829467e+08  79202.519273      0.0 -0.148352
# 1814198  6.705523e-08 -4.030179e+08  59746.212420      0.0 -0.154286
# 1814199 -7.823110e-08 -3.872451e+08  55738.564231      0.0 -0.143590
# 1814200  0.000000e+00 -4.151209e+08  54647.504718      0.0 -0.144330
# 1814201 -6.705523e-08 -4.485692e+08  44399.390719      0.0 -0.153005
#
# [1814202 rows x 17 columns]

# %%
# Out:
#                year        distw  comlang_off  comlang_ethno    comcol  \
# iso3_o
# ABW     2003.363939  9221.805463     0.136755       0.330929  0.008877
# AFG     1989.535683  7323.482165     0.010600       0.012942  0.000000
# AGO     1997.771202  7364.826130     0.034295       0.032562  0.023152
# ALB     1988.860695  6058.121464     0.000000       0.010146  0.000000
# AND     1994.318209  6262.621670     0.126584       0.129963  0.000000
# ...             ...          ...          ...            ...       ...
# YMD     1978.394541  6926.949156     0.123242       0.107803  0.303832
# YUG     1974.474079  6147.345346     0.000000       0.007680  0.000000
# ZAF     1988.860695  8501.273167     0.303016       0.309781  0.000000
# ZMB     1991.508264  7589.281329     0.315329       0.318772  0.291421
# ZWE     1991.508264  7845.847564     0.315329       0.318772  0.291421
#
#            col45     heg_o     heg_d  col_dep_ever  sibling_ever  \
# iso3_o
# ABW     0.005270  0.000000  0.005270      0.005270      0.019417
# AFG     0.000000  0.000000  0.006286      0.006286      0.343523
# AGO     0.005571  0.000000  0.005571      0.005571      0.026990
# ALB     0.000000  0.000000  0.006490      0.006490      0.068921
# AND     0.000000  0.000000  0.000000      0.000000      0.000000
# ...          ...       ...       ...           ...           ...
# YMD     0.006341  0.000000  0.000000      0.000000      0.000000
# YUG     0.000000  0.000000  0.000000      0.000000      0.073137
# ZAF     0.003656  0.003656  0.012980      0.016636      0.350731
# ZMB     0.005903  0.000000  0.005903      0.005903      0.347895
# ZWE     0.005903  0.000000  0.005903      0.005903      0.347895
#
#                gdp_o         gdp_d      tradeflow  both_eu    one_eu
# iso3_o
# ABW     2.098806e+06  2.383336e+08    7795.408595      0.0  0.146741
# AFG     7.078728e+06  1.716962e+08    1935.100106      0.0  0.144336
# AGO     3.651130e+07  2.094175e+08  103106.246930      0.0  0.139903
# ALB     4.549805e+06  1.596800e+08    3405.036503      0.0  0.147349
# AND     1.465294e+06  1.797410e+08     457.554118      0.0  0.138892
# ...              ...           ...            ...      ...       ...
# YMD     1.563708e+06  6.074459e+07    1283.330604      0.0  0.131514
# YUG     3.479484e+07  5.475623e+07   37138.198808      0.0  0.145575
# ZAF     1.404773e+08  1.589383e+08  185592.220631      0.0  0.147349
# ZMB     7.831689e+06  1.708264e+08   14535.385031      0.0  0.140397
# ZWE     7.397706e+06  1.708278e+08    8069.037425      0.0  0.140397
#
# [210 rows x 15 columns]
